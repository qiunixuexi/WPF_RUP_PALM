# %%
import torch
import platform
import sys

print("="*50)
print(f"OS: {platform.platform()}")
print(f"Python: {sys.version.split()[0]}")
print(f"PyTorch: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version (PyTorch built with): {torch.version.cuda}")
    print(f"cuDNN version: {torch.backends.cudnn.version()}")
    print(f"GPU: {torch.cuda.get_device_name(0)}")
print("="*50)
# Out:
# ...
# OS: Windows-10-10.0.22621-SP0
# Python: 3.8.19
# PyTorch: 2.4.1+cu118
# CUDA available: True
# CUDA version (PyTorch built with): 11.8
# cuDNN version: 90100
# GPU: NVIDIA GeForce RTX 4070 Ti SUPER
# ...

# %%
import torch, numpy, pandas, sklearn, matplotlib, seaborn, captum, scipy

print(f"torch=={torch.__version__}")
print(f"numpy=={numpy.__version__}")
print(f"pandas=={pandas.__version__}")
print(f"scikit-learn=={sklearn.__version__}")  
print(f"scipy=={scipy.__version__}")
print(f"matplotlib=={matplotlib.__version__}")
print(f"seaborn=={seaborn.__version__}")
print(f"captum=={captum.__version__}")
print(f'torch.backends.cudnn.version()=={torch.backends.cudnn.version()}')
# Out:
# torch==2.4.1+cu118
# numpy==1.24.3
# pandas==2.0.3
# scikit-learn==1.3.2
# scipy==1.10.1
# matplotlib==3.7.2
# seaborn==0.13.2
# captum==0.7.0
# torch.backends.cudnn.version()==90100

# %%
'''
Operating System: Windows 10
Python Version: 3.8.19
Hardware: NVIDIA GeForce RTX 4070 Ti SUPER
CUDA Toolkit: 11.8 (bundled with PyTorch)
cuDNN: 9.0.1 (version 90100)
Core Dependencies:
torch==2.4.1+cu118
numpy==1.24.3
pandas==2.0.3
scikit-learn==1.3.2
scipy==1.10.1
matplotlib==3.7.2
seaborn==0.13.2
captum==0.7.0
'''
# Out:
# 90100
